# %% [markdown]
# # Matrix Factorization и Factorization Machines

# %% [markdown]
# План семинара:
# 1. Теоретическое введение в Factorization Machines
# 2. Построение рекомендательной модели с помощью VW
# 3. Построение рекомендательной модели на основе SVD

# %%
import numpy as np
import pandas as pd
from scipy.sparse import coo_matrix, csr_matrix, csc_matrix
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics.pairwise import cosine_similarity

# %matplotlib inline

# %% [markdown]
# ## Подготовка данных

# %%
df = pd.read_csv("ml-20m/ratings.csv")

# %%
df.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1        2     3.5  1112486027
# 1       1       29     3.5  1112484676
# 2       1       32     3.5  1112484819
# 3       1       47     3.5  1112484727
# 4       1       50     3.5  1112484580

# %%
# Выбросим фильмы с < 5 рейтингами
group_sizes = df.groupby("movieId").size().reset_index()
blacklist = group_sizes[group_sizes[0] < 5].movieId
df = df[~df.movieId.isin(blacklist)]

# %%
print("Unique user count", len(df["userId"].unique()))
print("Unique movie count", len(df["movieId"].unique()))
# Out:
# Unique user count 138493
# Unique movie count 18345

# %%
index_to_item_id_mapping = [x for x in df["movieId"].sort_values().unique()]
item_id_to_index_mapping = {}
for index, value in enumerate(index_to_item_id_mapping, start=1):
    item_id_to_index_mapping[int(value)] = index

assert len(index_to_item_id_mapping) == 18345

# %%
df = pd.DataFrame.from_records(
    {"userId": row.userId, "movieId": item_id_to_index_mapping[int(row.movieId)], "rating": row.rating}
    for row in df.itertuples())

# %%
# Разобьем выборку на train & test выбросив случайные 7 рейтингов для каждого пользователя

df["random"] = np.random.random(size=(df.shape[0], 1))
idx = df.sort_values(by="random") \
    .reset_index() \
    .groupby("userId") \
    .head(n=7)["index"]

mask = df.index.isin(idx)
train_df = df[~mask]
test_df = df[mask]

# %%
train_df[["userId", "movieId", "rating"]].to_csv("ml20m_train.csv", header=False, index=False)
test_df[["userId", "movieId", "rating"]].to_csv("ml20m_test.csv", header=False, index=False)

# %% [markdown]
# ## Сборка и установка VW

# %% [markdown]
# 1. Можно собрать из исходников, они тут:
# https://github.com/JohnLangford/vowpal_wabbit/releases
# 2. Можно установить готовые бинарники:
#
#   Команда для Ubuntu: **apt-get install vowpal-wabbit**
#
#   Команада для Mac OS X: **brew install vowpal-wabbit** (предварительно надо установить brew: http://brew.sh/)

# %% [markdown]
# После установки нужно проверить, что бинарник есть:

# %%
# !vw --version
# Out:
# 8.5.0

# %% [markdown]
# ## Обучим VW

# %%
# !awk -F"," '{printf "%f |u %d |i %d\n", $3,$1,$2}' < ml20m_train.csv | \
  vw /dev/stdin -b 18 -q ui --rank 30 --l2 0.001 --learning_rate 0.015 \
    --passes 5 --decay_learning_rate 0.97 --power_t 0 \
    --loss_function squared -f movielens.reg --cache_file movielens.cache
# Out:
# creating quadratic features for pairs: ui
# using l2 regularization = 0.001
# final_regressor = movielens.reg
# Num weight bits = 18
# learning rate = 0.015
# initial_t = 1
# power_t = 0
# decay_learning_rate = 0.97
# using cache_file = movielens.cache
# ignoring text input in favor of cache input
# num sources = 1
# average  since         example        example  current  current  current
# loss     last          counter         weight    label  predict features
# 10.627020 10.627020            1            1.0   3.5000   0.2401       63
# 10.706633 10.786245            2            2.0   3.5000   0.2158       63
# 10.197121 9.687609            4            4.0   3.5000   0.4220       63
# 10.961847 11.726574            8            8.0   4.0000   0.6873       63
# 8.993563 7.025279           16           16.0   3.5000   1.1249       63
# 7.049418 5.105272           32           32.0   3.5000   1.8424       63
# 4.498373 1.947328           64           64.0   4.0000   2.8178       63
# 2.487681 0.476990          128          128.0   3.5000   3.4859       63
# 2.321730 2.155778          256          256.0   5.0000   3.6903       63
# 1.635113 0.948496          512          512.0   3.0000   3.5872       63
# 1.313782 0.992452         1024         1024.0   5.0000   4.0052       63
# 1.114065 0.914347         2048         2048.0   3.0000   3.6377       63
# 1.140698 1.167331         4096         4096.0   3.0000   3.6085       63
# 1.051875 0.963051         8192         8192.0   3.5000   3.2049       63
# 1.025668 0.999462        16384        16384.0   2.5000   3.4604       63
# 0.918741 0.811813        32768        32768.0   1.0000   3.2877       63
# 0.935687 0.952633        65536        65536.0   3.0000   4.1116       63
# 0.938516 0.941346       131072       131072.0   4.0000   3.5450       63
# 0.878510 0.818504       262144       262144.0   4.5000   3.1083       63
# 0.840900 0.803291       524288       524288.0   4.5000   3.7278       63
# 0.811443 0.781985      1048576      1048576.0   2.5000   3.4944       63
# 0.791100 0.770758      2097152      2097152.0   3.0000   2.6715       63
# 0.782344 0.773587      4194304      4194304.0   4.0000   4.0985       63
# 0.770046 0.757749      8388608      8388608.0   4.5000   3.7810       63
# 0.759361 0.748677     16777216     16777216.0   2.0000   3.2445       63
# 0.730118 0.730118     33554432     33554432.0   4.5000   4.1291       63 h
# 0.688193 0.646267     67108864     67108864.0   2.0000   1.8550       63 h
#
# finished run
# number of examples per pass = 17113116
# passes used = 5
# weighted example sum = 85565580.000000
# weighted label sum = 301258317.500000
# average loss = 0.616601 h
# best constant = 3.520788
# total feature number = 5390631540
# awk: write error on stdout
#  input record number 3648, file
#  source line number 1

# %%
# !awk -F"," '{printf "%f |u %d |i %d\n", $3,$1,$2}' < ml20m_test.csv | \
  vw /dev/stdin -i movielens.reg -t
# Out:
# creating quadratic features for pairs: ui
# only testing
# Num weight bits = 18
# learning rate = 10
# initial_t = 1
# power_t = 0.5
# using no cache
# Reading datafile = /dev/stdin
# num sources = 1
# average  since         example        example  current  current  current
# loss     last          counter         weight    label  predict features
# 0.049604 0.049604            1            1.0   3.5000   3.7227       63
# 0.063143 0.076681            2            2.0   3.5000   3.7769       63
# 0.117095 0.171048            4            4.0   4.0000   3.6406       63
# 0.148731 0.180367            8            8.0   5.0000   4.2999       63
# 0.257157 0.365583           16           16.0   5.0000   4.6183       63
# 0.291124 0.325091           32           32.0   5.0000   4.7100       63
# 0.668339 1.045555           64           64.0   4.0000   4.2800       63
# 0.659109 0.649879          128          128.0   2.0000   4.1230       63
# 0.724413 0.789716          256          256.0   3.0000   3.9349       63
# 0.734581 0.744750          512          512.0   4.0000   4.0929       63
# 0.759732 0.784883         1024         1024.0   3.0000   3.0492       63
# 0.746856 0.733980         2048         2048.0   3.0000   3.1479       63
# 0.725728 0.704600         4096         4096.0   3.0000   4.5786       63
# 0.739128 0.752527         8192         8192.0   3.0000   2.9300       63
# 0.728730 0.718333        16384        16384.0   3.0000   3.2625       63
# 0.739346 0.749961        32768        32768.0   3.0000   2.7855       63
# 0.736170 0.732994        65536        65536.0   5.0000   3.9600       63
# 0.742319 0.748467       131072       131072.0   4.0000   3.0304       63
# 0.743337 0.744356       262144       262144.0   2.0000   3.6454       63
# 0.741129 0.738920       524288       524288.0   5.0000   4.9291       63
#
# finished run
# number of examples per pass = 969451
# passes used = 1
# weighted example sum = 969451.000000
# weighted label sum = 3516617.500000
# average loss = 0.739978
# best constant = 3.627432
# total feature number = 61075413

# %%
np.sqrt(0.739978)
# Out:
# 0.86021973936895912

# %% [markdown]
# RMSE ~0.86, что хорошо!

# %% [markdown]
# ## Сравним с простым SVD

# %%
user_means = pd.DataFrame(train_df.groupby("userId").mean()["rating"]).reset_index()
work_df = pd.merge(train_df, user_means, on="userId")

# %%
work_df.head()
# Out:
#    movieId  rating_x  userId    random  rating_y
# 0       29       3.5       1  0.535317  3.741071
# 1       32       3.5       1  0.533745  3.741071
# 2       47       3.5       1  0.559406  3.741071
# 3       50       3.5       1  0.588092  3.741071
# 4      150       4.0       1  0.513574  3.741071

# %%
work_df["r"] = work_df["rating_x"] - work_df["rating_y"]

# %%
train_M = csr_matrix(
    (work_df["r"], (work_df["userId"] - 1, work_df["movieId"] - 1)), shape=(138493, 18345))

# %%
from scipy.sparse.linalg import svds

U, S, Vt = svds(train_M, k=30)

sum_ = 0
count = 0

for user_id, group in test_df.groupby("userId"):
    uvec = U[user_id - 1, :] * S
    
    movie_ids = group["movieId"].values - 1
    rating = group["rating"].values
    
    predicted = uvec.dot(Vt[:, movie_ids]) + \
        user_means[user_means["userId"] == user_id]["rating"].values[0]

    diff = (predicted - rating) ** 2
    sum_ += np.sum(diff)
    count += len(diff)

# %%
np.sqrt(sum_ / count)
# Out:
# 0.95067281590394248

# %% [markdown]
# ## Рекомендации

# %% [markdown]
# Нам понадобится g++ (и boost), чтобы собрать один примерчик. Установка boost аналогична установке VW:
#
#   Команда для Ubuntu: **apt-get install libboost-all-dev**
#
#   Команада для Mac OS X: **brew install boost** (предварительно надо установить brew: http://brew.sh/)

# %%
# !g++ --version
# Out:
# Configured with: --prefix=/Library/Developer/CommandLineTools/usr --with-gxx-include-dir=/usr/include/c++/4.2.1
# Apple LLVM version 8.1.0 (clang-802.0.42)
# Target: x86_64-apple-darwin16.6.0
# Thread model: posix
# InstalledDir: /Library/Developer/CommandLineTools/usr/bin

# %%
# !wget https://github.com/JohnLangford/vowpal_wabbit/archive/8.5.0.zip
# Out:
# --2017-12-11 15:28:10--  https://github.com/JohnLangford/vowpal_wabbit/archive/8.5.0.zip
# Resolving github.com... 192.30.253.112, 192.30.253.113
# Connecting to github.com|192.30.253.112|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://codeload.github.com/JohnLangford/vowpal_wabbit/zip/8.5.0 [following]
# --2017-12-11 15:28:11--  https://codeload.github.com/JohnLangford/vowpal_wabbit/zip/8.5.0
# Resolving codeload.github.com... 192.30.253.121, 192.30.253.120
# Connecting to codeload.github.com|192.30.253.121|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘8.5.0.zip’
#
# 8.5.0.zip               [   <=>              ]  18.45M  44.9KB/s    in 3m 40s
#
# 2017-12-11 15:31:51 (86.1 KB/s) - ‘8.5.0.zip’ saved [19350154]

# %%
# !unzip 8.5.0.zip
# Out:
# Archive:  8.5.0.zip
# 769cba5b44450401500f39ee70c0950353368cb0
#    creating: vowpal_wabbit-8.5.0/
#   inflating: vowpal_wabbit-8.5.0/.editorconfig
#   inflating: vowpal_wabbit-8.5.0/.gitignore
#  extracting: vowpal_wabbit-8.5.0/.gitkeep
#   inflating: vowpal_wabbit-8.5.0/.travis.yml
#   inflating: vowpal_wabbit-8.5.0/AUTHORS
#   inflating: vowpal_wabbit-8.5.0/COPYING
#   inflating: vowpal_wabbit-8.5.0/INSTALL
#   inflating: vowpal_wabbit-8.5.0/LICENSE
#   inflating: vowpal_wabbit-8.5.0/Makefile.am
#   inflating: vowpal_wabbit-8.5.0/Makefile.in
#    creating: vowpal_wabbit-8.5.0/R/
#   inflating: vowpal_wabbit-8.5.0/R/example.yaml
#    creating: vowpal_wabbit-8.5.0/R/examples/
#   inflating: vowpal_wabbit-8.5.0/R/examples/vw_example.R
#   inflating: vowpal_wabbit-8.5.0/R/examples/vw_example_2.R
#    creating: vowpal_wabbit-8.5.0/R/r.vw/
#   inflating: vowpal_wabbit-8.5.0/R/r.vw/DESCRIPTION
#   inflating: vowpal_wabbit-8.5.0/R/r.vw/NAMESPACE
#    creating: vowpal_wabbit-8.5.0/R/r.vw/R/
#   inflating: vowpal_wabbit-8.5.0/R/r.vw/R/dt2vw.R
#   inflating: vowpal_wabbit-8.5.0/R/r.vw/R/vw.R
#    creating: vowpal_wabbit-8.5.0/R/r.vw/man/
#   inflating: vowpal_wabbit-8.5.0/R/r.vw/man/dt2vw.Rd
#   inflating: vowpal_wabbit-8.5.0/R/r.vw/man/vw.Rd
#   inflating: vowpal_wabbit-8.5.0/R/rscripts_readme.md
#   inflating: vowpal_wabbit-8.5.0/README.deploy.txt
#   inflating: vowpal_wabbit-8.5.0/README.md
#   inflating: vowpal_wabbit-8.5.0/README.windows.txt
#    creating: vowpal_wabbit-8.5.0/acinclude.d/
#   inflating: vowpal_wabbit-8.5.0/acinclude.d/ax_boost_base.m4
#   inflating: vowpal_wabbit-8.5.0/acinclude.d/ax_boost_program_options.m4
#   inflating: vowpal_wabbit-8.5.0/acinclude.d/ax_check_zlib.m4
#   inflating: vowpal_wabbit-8.5.0/acinclude.d/ax_cxx_compile_stdcxx_11.m4
#   inflating: vowpal_wabbit-8.5.0/acinclude.d/ax_pthread.m4
#   inflating: vowpal_wabbit-8.5.0/acinclude.d/libtool.m4
#   inflating: vowpal_wabbit-8.5.0/acinclude.d/ltoptions.m4
#   inflating: vowpal_wabbit-8.5.0/acinclude.d/ltsugar.m4
#   inflating: vowpal_wabbit-8.5.0/acinclude.d/ltversion.m4
#   inflating: vowpal_wabbit-8.5.0/acinclude.d/lt~obsolete.m4
#   inflating: vowpal_wabbit-8.5.0/aclocal.m4
#   inflating: vowpal_wabbit-8.5.0/appveyor.yml
#   inflating: vowpal_wabbit-8.5.0/autogen.sh
#    creating: vowpal_wabbit-8.5.0/big_tests/
#   inflating: vowpal_wabbit-8.5.0/big_tests/HOWTO.use_it.txt
#   inflating: vowpal_wabbit-8.5.0/big_tests/HOWTO.write_new_tests.txt
#   inflating: vowpal_wabbit-8.5.0/big_tests/Makefile
#     linking: vowpal_wabbit-8.5.0/big_tests/README.txt  -> HOWTO.use_it.txt
#   inflating: vowpal_wabbit-8.5.0/big_tests/dataSets.mk
#    creating: vowpal_wabbit-8.5.0/big_tests/expected/
#    creating: vowpal_wabbit-8.5.0/big_tests/expected/1a/
#  extracting: vowpal_wabbit-8.5.0/big_tests/expected/1a/err
#  extracting: vowpal_wabbit-8.5.0/big_tests/expected/1a/out
#    creating: vowpal_wabbit-8.5.0/big_tests/expected/1b/
#  extracting: vowpal_wabbit-8.5.0/big_tests/expected/1b/err
#  extracting: vowpal_wabbit-8.5.0/big_tests/expected/1b/out
#    creating: vowpal_wabbit-8.5.0/big_tests/expected/2/
#  extracting: vowpal_wabbit-8.5.0/big_tests/expected/2/err
#  extracting: vowpal_wabbit-8.5.0/big_tests/expected/2/out
#    creating: vowpal_wabbit-8.5.0/big_tests/expected/3/
#  extracting: vowpal_wabbit-8.5.0/big_tests/expected/3/err
#  extracting: vowpal_wabbit-8.5.0/big_tests/expected/3/out
#    creating: vowpal_wabbit-8.5.0/big_tests/expected/4a/
#  extracting: vowpal_wabbit-8.5.0/big_tests/expected/4a/err
#  extracting: vowpal_wabbit-8.5.0/big_tests/expected/4a/out
#    creating: vowpal_wabbit-8.5.0/big_tests/expected/4b/
#  extracting: vowpal_wabbit-8.5.0/big_tests/expected/4b/err
#  extracting: vowpal_wabbit-8.5.0/big_tests/expected/4b/out
#    creating: vowpal_wabbit-8.5.0/big_tests/expected/5a/
#  extracting: vowpal_wabbit-8.5.0/big_tests/expected/5a/err
#  extracting: vowpal_wabbit-8.5.0/big_tests/expected/5a/out
#    creating: vowpal_wabbit-8.5.0/big_tests/expected/5b/
#  extracting: vowpal_wabbit-8.5.0/big_tests/expected/5b/err
#  extracting: vowpal_wabbit-8.5.0/big_tests/expected/5b/out
#    creating: vowpal_wabbit-8.5.0/big_tests/expected/6a/
#  extracting: vowpal_wabbit-8.5.0/big_tests/expected/6a/err
#  extracting: vowpal_wabbit-8.5.0/big_tests/expected/6a/out
#    creating: vowpal_wabbit-8.5.0/big_tests/expected/6b/
#  extracting: vowpal_wabbit-8.5.0/big_tests/expected/6b/err
#  extracting: vowpal_wabbit-8.5.0/big_tests/expected/6b/out
#    creating: vowpal_wabbit-8.5.0/big_tests/testCode/
#   inflating: vowpal_wabbit-8.5.0/big_tests/testCode/URLRep.munge.sh
#   inflating: vowpal_wabbit-8.5.0/big_tests/testCode/covtype.munge.sh
#   inflating: vowpal_wabbit-8.5.0/big_tests/testCode/floatingTolerance.pl
#   inflating: vowpal_wabbit-8.5.0/big_tests/testCode/mnist.extract-labels.pl
#   inflating: vowpal_wabbit-8.5.0/big_tests/testCode/mnist.extractfeatures.cpp
#   inflating: vowpal_wabbit-8.5.0/big_tests/testCode/mnist.extractpixels.cpp
#   inflating: vowpal_wabbit-8.5.0/big_tests/testCode/mnist.munge.sh
#   inflating: vowpal_wabbit-8.5.0/big_tests/testCode/movielensRatings2vw.pl
#   inflating: vowpal_wabbit-8.5.0/big_tests/testCode/ocr2vw.py
#   inflating: vowpal_wabbit-8.5.0/big_tests/testCode/shuffle.pl
#   inflating: vowpal_wabbit-8.5.0/big_tests/testCode/svml2vw.pl
#   inflating: vowpal_wabbit-8.5.0/big_tests/testDetails.mk
#   inflating: vowpal_wabbit-8.5.0/big_tests/testGroups.mk
#    creating: vowpal_wabbit-8.5.0/c_test/
#   inflating: vowpal_wabbit-8.5.0/c_test/c_test.vcxproj
#   inflating: vowpal_wabbit-8.5.0/c_test/sample.c
#    creating: vowpal_wabbit-8.5.0/cluster/
#   inflating: vowpal_wabbit-8.5.0/cluster/Makefile.am
#   inflating: vowpal_wabbit-8.5.0/cluster/Makefile.in
#   inflating: vowpal_wabbit-8.5.0/cluster/README_cluster
#   inflating: vowpal_wabbit-8.5.0/cluster/cluster.vcxproj
#   inflating: vowpal_wabbit-8.5.0/cluster/mapscript-yarn.sh
#   inflating: vowpal_wabbit-8.5.0/cluster/mapscript.sh
#   inflating: vowpal_wabbit-8.5.0/cluster/runvw-yarn.sh
#   inflating: vowpal_wabbit-8.5.0/cluster/runvw.sh
#   inflating: vowpal_wabbit-8.5.0/cluster/single_machine
#   inflating: vowpal_wabbit-8.5.0/cluster/spanning_tree_main.cc
#    creating: vowpal_wabbit-8.5.0/cluster/spark/
#   inflating: vowpal_wabbit-8.5.0/cluster/spark/VwSparkCluster.scala
#   inflating: vowpal_wabbit-8.5.0/config.guess
#   inflating: vowpal_wabbit-8.5.0/config.status
#   inflating: vowpal_wabbit-8.5.0/config.sub
#   inflating: vowpal_wabbit-8.5.0/configure
#   inflating: vowpal_wabbit-8.5.0/configure.ac
#    creating: vowpal_wabbit-8.5.0/cs/
#    creating: vowpal_wabbit-8.5.0/cs/azure/
#   inflating: vowpal_wabbit-8.5.0/cs/azure/ApplicationInsights.config
#    creating: vowpal_wabbit-8.5.0/cs/azure/Join/
#   inflating: vowpal_wabbit-8.5.0/cs/azure/Join/QueueDictionary.cs
#    creating: vowpal_wabbit-8.5.0/cs/azure/Properties/
#   inflating: vowpal_wabbit-8.5.0/cs/azure/Properties/AssemblyInfo.cs
#    creating: vowpal_wabbit-8.5.0/cs/azure/Trainer/
#    creating: vowpal_wabbit-8.5.0/cs/azure/Trainer/Checkpoint/
#   inflating: vowpal_wabbit-8.5.0/cs/azure/Trainer/Checkpoint/CountingCheckpointPolicy.cs
#   inflating: vowpal_wabbit-8.5.0/cs/azure/Trainer/Checkpoint/ICheckpointPolicy.cs
#   inflating: vowpal_wabbit-8.5.0/cs/azure/Trainer/Checkpoint/TimespanCheckpointPolicy.cs
#    creating: vowpal_wabbit-8.5.0/cs/azure/Trainer/Data/
#   inflating: vowpal_wabbit-8.5.0/cs/azure/Trainer/Data/CheckpointData.cs
#   inflating: vowpal_wabbit-8.5.0/cs/azure/Trainer/Data/CheckpointEvaluateTriggerEvent.cs
#   inflating: vowpal_wabbit-8.5.0/cs/azure/Trainer/Data/CheckpointTriggerEvent.cs
#   inflating: vowpal_wabbit-8.5.0/cs/azure/Trainer/Data/PipelineData.cs
#   inflating: vowpal_wabbit-8.5.0/cs/azure/Trainer/Data/TrainerResult.cs
#   inflating: vowpal_wabbit-8.5.0/cs/azure/Trainer/LearnEventProcessor.cs
#   inflating: vowpal_wabbit-8.5.0/cs/azure/Trainer/LearnEventProcessorFactory.cs
#   inflating: vowpal_wabbit-8.5.0/cs/azure/Trainer/LearnEventProcessorHost.cs
#   inflating: vowpal_wabbit-8.5.0/cs/azure/Trainer/Learner.cs
#   inflating: vowpal_wabbit-8.5.0/cs/azure/Trainer/OnlineTrainerSettings.cs
#   inflating: vowpal_wabbit-8.5.0/cs/azure/Trainer/OnlineTrainerSettingsInternal.cs
#   inflating: vowpal_wabbit-8.5.0/cs/azure/Trainer/OnlineTrainerState.cs
#    creating: vowpal_wabbit-8.5.0/cs/azure/Trainer/Operations/
#   inflating: vowpal_wabbit-8.5.0/cs/azure/Trainer/Operations/CheckPointOperation.cs
#   inflating: vowpal_wabbit-8.5.0/cs/azure/Trainer/Operations/EvalOperation.cs
#   inflating: vowpal_wabbit-8.5.0/cs/azure/Trainer/Operations/InitializeOperation.cs
#   inflating: vowpal_wabbit-8.5.0/cs/azure/Trainer/Operations/LatencyOperation.cs
#   inflating: vowpal_wabbit-8.5.0/cs/azure/Trainer/Operations/LearnOperation.cs
#   inflating: vowpal_wabbit-8.5.0/cs/azure/Trainer/Operations/ThrottledOperation.cs
#   inflating: vowpal_wabbit-8.5.0/cs/azure/Trainer/PerformanceCounters.cs
#    creating: vowpal_wabbit-8.5.0/cs/azure/Trainer/Util/
#   inflating: vowpal_wabbit-8.5.0/cs/azure/Trainer/Util/ExtensionMethods.cs
#   inflating: vowpal_wabbit-8.5.0/cs/azure/Trainer/Util/SafeTimer.cs
#   inflating: vowpal_wabbit-8.5.0/cs/azure/app.config
#   inflating: vowpal_wabbit-8.5.0/cs/azure/azure.csproj
#   inflating: vowpal_wabbit-8.5.0/cs/azure/azure.nuspec
#   inflating: vowpal_wabbit-8.5.0/cs/azure/packages.config
#    creating: vowpal_wabbit-8.5.0/cs/azure_service/
#   inflating: vowpal_wabbit-8.5.0/cs/azure_service/DownloadServiceConfiguration.ps1
#    creating: vowpal_wabbit-8.5.0/cs/azure_service/OnlineTrainerContent/
#   inflating: vowpal_wabbit-8.5.0/cs/azure_service/OnlineTrainerContent/GCSettingsManagement.ps1
#   inflating: vowpal_wabbit-8.5.0/cs/azure_service/OnlineTrainerContent/ServerGC.cmd
#   inflating: vowpal_wabbit-8.5.0/cs/azure_service/OnlineTrainerContent/diagnostics.wadcfgx
#   inflating: vowpal_wabbit-8.5.0/cs/azure_service/OnlineTrainerContent/install.cmd
#   inflating: vowpal_wabbit-8.5.0/cs/azure_service/RoleProperties.txt
#   inflating: vowpal_wabbit-8.5.0/cs/azure_service/ServiceConfiguration.Cloud.cscfg
#   inflating: vowpal_wabbit-8.5.0/cs/azure_service/ServiceConfiguration.Local.cscfg
#   inflating: vowpal_wabbit-8.5.0/cs/azure_service/ServiceConfiguration.cscfg
#   inflating: vowpal_wabbit-8.5.0/cs/azure_service/ServiceDefinition.csdef
#   inflating: vowpal_wabbit-8.5.0/cs/azure_service/azure_service.ccproj
#    creating: vowpal_wabbit-8.5.0/cs/azure_worker/
#   inflating: vowpal_wabbit-8.5.0/cs/azure_worker/CheckpointController.cs
#   inflating: vowpal_wabbit-8.5.0/cs/azure_worker/OnlineTrainerController.cs
#   inflating: vowpal_wabbit-8.5.0/cs/azure_worker/OnlineTrainerSettingsDownloader.cs
#   inflating: vowpal_wabbit-8.5.0/cs/azure_worker/OnlineTrainerSettingsWatcher.cs
#    creating: vowpal_wabbit-8.5.0/cs/azure_worker/Properties/
#   inflating: vowpal_wabbit-8.5.0/cs/azure_worker/Properties/AssemblyInfo.cs
#   inflating: vowpal_wabbit-8.5.0/cs/azure_worker/ResetController.cs
#   inflating: vowpal_wabbit-8.5.0/cs/azure_worker/StatusController.cs
#   inflating: vowpal_wabbit-8.5.0/cs/azure_worker/WorkerRole.cs
#   inflating: vowpal_wabbit-8.5.0/cs/azure_worker/app.config
#   inflating: vowpal_wabbit-8.5.0/cs/azure_worker/azure_worker.csproj
#   inflating: vowpal_wabbit-8.5.0/cs/azure_worker/packages.config
#    creating: vowpal_wabbit-8.5.0/cs/cli/
#   inflating: vowpal_wabbit-8.5.0/cs/cli/AssemblyInfo.cpp
#   inflating: vowpal_wabbit-8.5.0/cs/cli/Resource.rc
#   inflating: vowpal_wabbit-8.5.0/cs/cli/clr_io.cpp
#   inflating: vowpal_wabbit-8.5.0/cs/cli/clr_io.h
#   inflating: vowpal_wabbit-8.5.0/cs/cli/clr_io_memory.cpp
#   inflating: vowpal_wabbit-8.5.0/cs/cli/clr_io_memory.h
#   inflating: vowpal_wabbit-8.5.0/cs/cli/cs_vld.vcxproj
#   inflating: vowpal_wabbit-8.5.0/cs/cli/cs_vld.vcxproj.filters
#   inflating: vowpal_wabbit-8.5.0/cs/cli/packages.config
#   inflating: vowpal_wabbit-8.5.0/cs/cli/resource.h
#   inflating: vowpal_wabbit-8.5.0/cs/cli/spanning_tree_clr.cpp
#   inflating: vowpal_wabbit-8.5.0/cs/cli/spanning_tree_clr.h
#   inflating: vowpal_wabbit-8.5.0/cs/cli/vld_clr.cpp
#   inflating: vowpal_wabbit-8.5.0/cs/cli/vld_clr.h
#   inflating: vowpal_wabbit-8.5.0/cs/cli/vowpalwabbit.cpp
#   inflating: vowpal_wabbit-8.5.0/cs/cli/vowpalwabbit.h
#   inflating: vowpal_wabbit-8.5.0/cs/cli/vw_arguments.h
#   inflating: vowpal_wabbit-8.5.0/cs/cli/vw_base.cpp
#   inflating: vowpal_wabbit-8.5.0/cs/cli/vw_base.h
#   inflating: vowpal_wabbit-8.5.0/cs/cli/vw_builder.cpp
#   inflating: vowpal_wabbit-8.5.0/cs/cli/vw_builder.h
#   inflating: vowpal_wabbit-8.5.0/cs/cli/vw_cbutil.cpp
#   inflating: vowpal_wabbit-8.5.0/cs/cli/vw_cbutil.h
#   inflating: vowpal_wabbit-8.5.0/cs/cli/vw_clr.h
#   inflating: vowpal_wabbit-8.5.0/cs/cli/vw_clr.vcxproj
#   inflating: vowpal_wabbit-8.5.0/cs/cli/vw_clr.vcxproj.filters
#   inflating: vowpal_wabbit-8.5.0/cs/cli/vw_example.cpp
#   inflating: vowpal_wabbit-8.5.0/cs/cli/vw_example.h
#   inflating: vowpal_wabbit-8.5.0/cs/cli/vw_exception.cpp
#   inflating: vowpal_wabbit-8.5.0/cs/cli/vw_interface.h
#   inflating: vowpal_wabbit-8.5.0/cs/cli/vw_label.h
#   inflating: vowpal_wabbit-8.5.0/cs/cli/vw_labelcomparator.h
#   inflating: vowpal_wabbit-8.5.0/cs/cli/vw_model.cpp
#   inflating: vowpal_wabbit-8.5.0/cs/cli/vw_model.h
#   inflating: vowpal_wabbit-8.5.0/cs/cli/vw_prediction.cpp
#   inflating: vowpal_wabbit-8.5.0/cs/cli/vw_prediction.h
#   inflating: vowpal_wabbit-8.5.0/cs/cli/vw_settings.h
#    creating: vowpal_wabbit-8.5.0/cs/common/
#   inflating: vowpal_wabbit-8.5.0/cs/common/Bag.cs
#    creating: vowpal_wabbit-8.5.0/cs/common/Properties/
#   inflating: vowpal_wabbit-8.5.0/cs/common/Properties/AssemblyInfo.cs
#    creating: vowpal_wabbit-8.5.0/cs/common/Reflection/
#   inflating: vowpal_wabbit-8.5.0/cs/common/Reflection/InspectionHelper.cs
#   inflating: vowpal_wabbit-8.5.0/cs/common/Reflection/ReflectionHelper.cs
#   inflating: vowpal_wabbit-8.5.0/cs/common/Reflection/TypeDistance.cs
#   inflating: vowpal_wabbit-8.5.0/cs/common/Reflection/TypeMatch.cs
#    creating: vowpal_wabbit-8.5.0/cs/common/Serializer/
#   inflating: vowpal_wabbit-8.5.0/cs/common/Serializer/FeatureExpression.cs
#   inflating: vowpal_wabbit-8.5.0/cs/common/Serializer/LabelExpression.cs
#   inflating: vowpal_wabbit-8.5.0/cs/common/Serializer/PropertyConfiguration.cs
#   inflating: vowpal_wabbit-8.5.0/cs/common/Serializer/Schema.cs
#   inflating: vowpal_wabbit-8.5.0/cs/common/Serializer/StringProcessing.cs
#   inflating: vowpal_wabbit-8.5.0/cs/common/VowpalWabbitDecisionServiceInteractionHeader.cs
#   inflating: vowpal_wabbit-8.5.0/cs/common/packages.config
#   inflating: vowpal_wabbit-8.5.0/cs/common/vw_common.csproj
#    creating: vowpal_wabbit-8.5.0/cs/cs/
#   inflating: vowpal_wabbit-8.5.0/cs/cs/ActionDependentFeature.cs
#   inflating: vowpal_wabbit-8.5.0/cs/cs/Extensions.cs
#   inflating: vowpal_wabbit-8.5.0/cs/cs/ObjectFactory.cs
#   inflating: vowpal_wabbit-8.5.0/cs/cs/ObjectPool.cs
#   inflating: vowpal_wabbit-8.5.0/cs/cs/PooledObject.cs
#    creating: vowpal_wabbit-8.5.0/cs/cs/Properties/
#   inflating: vowpal_wabbit-8.5.0/cs/cs/Properties/AssemblyInfo.cs
#   inflating: vowpal_wabbit-8.5.0/cs/cs/Properties/AssemblyInfoInternal.cs
#    creating: vowpal_wabbit-8.5.0/cs/cs/Serializer/
#   inflating: vowpal_wabbit-8.5.0/cs/cs/Serializer/AnnotationInspector.cs
#    creating: vowpal_wabbit-8.5.0/cs/cs/Serializer/Attributes/
#   inflating: vowpal_wabbit-8.5.0/cs/cs/Serializer/Attributes/CacheableAttribute.cs
#   inflating: vowpal_wabbit-8.5.0/cs/cs/Serializer/Attributes/FeatureAttribute.cs
#   inflating: vowpal_wabbit-8.5.0/cs/cs/Serializer/Attributes/LabelAttribute.cs
#   inflating: vowpal_wabbit-8.5.0/cs/cs/Serializer/ConfigInspector.cs
#   inflating: vowpal_wabbit-8.5.0/cs/cs/Serializer/IVowpalWabbitConverter.cs
#   inflating: vowpal_wabbit-8.5.0/cs/cs/Serializer/IVowpalWabbitMultiExampleSerializerCompiler.cs
#   inflating: vowpal_wabbit-8.5.0/cs/cs/Serializer/IVowpalWabbitSerializer.cs
#   inflating: vowpal_wabbit-8.5.0/cs/cs/Serializer/IVowpalWabbitSerializerCompiler.cs
#    creating: vowpal_wabbit-8.5.0/cs/cs/Serializer/Intermediate/
#   inflating: vowpal_wabbit-8.5.0/cs/cs/Serializer/Intermediate/EnumerizedFeature.cs
#   inflating: vowpal_wabbit-8.5.0/cs/cs/Serializer/Intermediate/Feature.cs
#   inflating: vowpal_wabbit-8.5.0/cs/cs/Serializer/Intermediate/Namespace.cs
#   inflating: vowpal_wabbit-8.5.0/cs/cs/Serializer/Intermediate/PreHashedFeature.cs
#   inflating: vowpal_wabbit-8.5.0/cs/cs/Serializer/VowpalWabbitConstants.cs
#   inflating: vowpal_wabbit-8.5.0/cs/cs/Serializer/VowpalWabbitDefaultMarshaller.cs
#   inflating: vowpal_wabbit-8.5.0/cs/cs/Serializer/VowpalWabbitDefaultMarshallerExt.tt
#   inflating: vowpal_wabbit-8.5.0/cs/cs/Serializer/VowpalWabbitMarshalContext.cs
#   inflating: vowpal_wabbit-8.5.0/cs/cs/Serializer/VowpalWabbitMultiExampleSerializer.cs
#   inflating: vowpal_wabbit-8.5.0/cs/cs/Serializer/VowpalWabbitMultiExampleSerializerCompiler.cs
#   inflating: vowpal_wabbit-8.5.0/cs/cs/Serializer/VowpalWabbitSerializerFactory.cs
#   inflating: vowpal_wabbit-8.5.0/cs/cs/Serializer/VowpalWabbitSingleExampleSerializer.cs
#   inflating: vowpal_wabbit-8.5.0/cs/cs/Serializer/VowpalWabbitSingleExampleSerializerCompiler.cs
#   inflating: vowpal_wabbit-8.5.0/cs/cs/VowpalWabbit.cs
#   inflating: vowpal_wabbit-8.5.0/cs/cs/VowpalWabbitDynamic.cs
#   inflating: vowpal_wabbit-8.5.0/cs/cs/VowpalWabbitExampleCollection.cs
#   inflating: vowpal_wabbit-8.5.0/cs/cs/VowpalWabbitMultiLine.cs
#   inflating: vowpal_wabbit-8.5.0/cs/cs/VowpalWabbitMultiLineExampleCollection.cs
#   inflating: vowpal_wabbit-8.5.0/cs/cs/VowpalWabbitMultiworldTesting.cs
#   inflating: vowpal_wabbit-8.5.0/cs/cs/VowpalWabbitSerializationException.cs
#   inflating: vowpal_wabbit-8.5.0/cs/cs/VowpalWabbitSingleLineExampleCollection.cs
#   inflating: vowpal_wabbit-8.5.0/cs/cs/VowpalWabbitSweep.cs
#   inflating: vowpal_wabbit-8.5.0/cs/cs/VowpalWabbitThreadedPrediction.cs
#   inflating: vowpal_wabbit-8.5.0/cs/cs/VowpalWabbitThreadedPredictionBase.cs
#   inflating: vowpal_wabbit-8.5.0/cs/cs/cs.csproj
#   inflating: vowpal_wabbit-8.5.0/cs/cs/cs.nuspec
#   inflating: vowpal_wabbit-8.5.0/cs/cs/packages.config
#   inflating: vowpal_wabbit-8.5.0/cs/cs/web.config.transform
#    creating: vowpal_wabbit-8.5.0/cs/cs_console/
#   inflating: vowpal_wabbit-8.5.0/cs/cs_console/App.config
#   inflating: vowpal_wabbit-8.5.0/cs/cs_console/Program.cs
#    creating: vowpal_wabbit-8.5.0/cs/cs_console/Properties/
#   inflating: vowpal_wabbit-8.5.0/cs/cs_console/Properties/AssemblyInfo.cs
#   inflating: vowpal_wabbit-8.5.0/cs/cs_console/cs_console.csproj
#   inflating: vowpal_wabbit-8.5.0/cs/cs_console/packages.config
#   inflating: vowpal_wabbit-8.5.0/cs/cs_console/setenv.bat
#    creating: vowpal_wabbit-8.5.0/cs/cs_json/
#    creating: vowpal_wabbit-8.5.0/cs/cs_json/Properties/
#   inflating: vowpal_wabbit-8.5.0/cs/cs_json/Properties/AssemblyInfo.cs
#    creating: vowpal_wabbit-8.5.0/cs/cs_json/Serializer/
#   inflating: vowpal_wabbit-8.5.0/cs/cs_json/Serializer/IVowpalWabbitJsonConverter.cs
#   inflating: vowpal_wabbit-8.5.0/cs/cs_json/Serializer/JsonRawStringConverter.cs
#   inflating: vowpal_wabbit-8.5.0/cs/cs_json/Serializer/JsonRawStringListConverter.cs
#   inflating: vowpal_wabbit-8.5.0/cs/cs_json/Serializer/JsonTypeInspector.cs
#   inflating: vowpal_wabbit-8.5.0/cs/cs_json/Serializer/PrefixedJsonReader.cs
#   inflating: vowpal_wabbit-8.5.0/cs/cs_json/Serializer/VowpalWabbitJsonBuilder.cs
#   inflating: vowpal_wabbit-8.5.0/cs/cs_json/Serializer/VowpalWabbitJsonException.cs
#   inflating: vowpal_wabbit-8.5.0/cs/cs_json/Serializer/VowpalWabbitJsonOptimizedSerializable.cs
#   inflating: vowpal_wabbit-8.5.0/cs/cs_json/Serializer/VowpalWabbitJsonReferenceResolver.cs
#   inflating: vowpal_wabbit-8.5.0/cs/cs_json/Serializer/VowpalWabbitJsonSerializable.cs
#   inflating: vowpal_wabbit-8.5.0/cs/cs_json/Serializer/VowpalWabbitJsonSerializer.cs
#   inflating: vowpal_wabbit-8.5.0/cs/cs_json/VowpalWabbitJson.cs
#   inflating: vowpal_wabbit-8.5.0/cs/cs_json/VowpalWabbitJsonThreadedPrediction.cs
#   inflating: vowpal_wabbit-8.5.0/cs/cs_json/VowpalWabbitMarshalAction.cs
#   inflating: vowpal_wabbit-8.5.0/cs/cs_json/cs_json.csproj
#   inflating: vowpal_wabbit-8.5.0/cs/cs_json/cs_json.nuspec
#   inflating: vowpal_wabbit-8.5.0/cs/cs_json/packages.config
#    creating: vowpal_wabbit-8.5.0/cs/cs_parallel/
#    creating: vowpal_wabbit-8.5.0/cs/cs_parallel/Properties/
#   inflating: vowpal_wabbit-8.5.0/cs/cs_parallel/Properties/AssemblyInfo.cs
#   inflating: vowpal_wabbit-8.5.0/cs/cs_parallel/VowpalWabbitAsync.cs
#   inflating: vowpal_wabbit-8.5.0/cs/cs_parallel/VowpalWabbitThreadedLearning.cs
#   inflating: vowpal_wabbit-8.5.0/cs/cs_parallel/cs_parallel.csproj
#   inflating: vowpal_wabbit-8.5.0/cs/cs_parallel/cs_parallel.nuspec
#   inflating: vowpal_wabbit-8.5.0/cs/cs_parallel/packages.config
#    creating: vowpal_wabbit-8.5.0/cs/cs_unittest_nofriend/
#    creating: vowpal_wabbit-8.5.0/cs/cs_unittest_nofriend/Properties/
#   inflating: vowpal_wabbit-8.5.0/cs/cs_unittest_nofriend/Properties/AssemblyInfo.cs
#   inflating: vowpal_wabbit-8.5.0/cs/cs_unittest_nofriend/TestSerializer.cs
#   inflating: vowpal_wabbit-8.5.0/cs/cs_unittest_nofriend/cs_unittest_nofriend.csproj
#    creating: vowpal_wabbit-8.5.0/cs/leaktest/
#    creating: vowpal_wabbit-8.5.0/cs/leaktest/Properties/
#   inflating: vowpal_wabbit-8.5.0/cs/leaktest/Properties/AssemblyInfo.cs
#   inflating: vowpal_wabbit-8.5.0/cs/leaktest/TestLeak.cs
#   inflating: vowpal_wabbit-8.5.0/cs/leaktest/TestWrapped.cs
#   inflating: vowpal_wabbit-8.5.0/cs/leaktest/TestWrappedBase.cs
#   inflating: vowpal_wabbit-8.5.0/cs/leaktest/cs_leaktest.csproj
#    creating: vowpal_wabbit-8.5.0/cs/setup/
#   inflating: vowpal_wabbit-8.5.0/cs/setup/Product.wxs
#   inflating: vowpal_wabbit-8.5.0/cs/setup/packages.config
#   inflating: vowpal_wabbit-8.5.0/cs/setup/setup.wixproj
#    creating: vowpal_wabbit-8.5.0/cs/setup_bundle/
#   inflating: vowpal_wabbit-8.5.0/cs/setup_bundle/Product.wxs
#   inflating: vowpal_wabbit-8.5.0/cs/setup_bundle/packages.config
#   inflating: vowpal_wabbit-8.5.0/cs/setup_bundle/setup_bundle.wixproj
#    creating: vowpal_wabbit-8.5.0/cs/test/
#   inflating: vowpal_wabbit-8.5.0/cs/test/AttributesSample.cs
#   inflating: vowpal_wabbit-8.5.0/cs/test/NIPS2015Tutorial.cs
#   inflating: vowpal_wabbit-8.5.0/cs/test/Program.cs
#    creating: vowpal_wabbit-8.5.0/cs/test/Properties/
#   inflating: vowpal_wabbit-8.5.0/cs/test/Properties/AssemblyInfo.cs
#   inflating: vowpal_wabbit-8.5.0/cs/test/VowpalWabbitInterface.cs
#   inflating: vowpal_wabbit-8.5.0/cs/test/app.config
#   inflating: vowpal_wabbit-8.5.0/cs/test/cs_test.csproj
#    creating: vowpal_wabbit-8.5.0/cs/testcommon/
#   inflating: vowpal_wabbit-8.5.0/cs/testcommon/ITestRunner.cs
#    creating: vowpal_wabbit-8.5.0/cs/testcommon/Properties/
#   inflating: vowpal_wabbit-8.5.0/cs/testcommon/Properties/AssemblyInfo.cs
#   inflating: vowpal_wabbit-8.5.0/cs/testcommon/cs_testcommon.csproj
#    creating: vowpal_wabbit-8.5.0/cs/testhelp/
#   inflating: vowpal_wabbit-8.5.0/cs/testhelp/App.config
#   inflating: vowpal_wabbit-8.5.0/cs/testhelp/DiscoverUnitTests.cs
#   inflating: vowpal_wabbit-8.5.0/cs/testhelp/Program.cs
#    creating: vowpal_wabbit-8.5.0/cs/testhelp/Properties/
#   inflating: vowpal_wabbit-8.5.0/cs/testhelp/Properties/AssemblyInfo.cs
#   inflating: vowpal_wabbit-8.5.0/cs/testhelp/cs_testhelp.csproj
#   inflating: vowpal_wabbit-8.5.0/cs/testhelp/packages.config
#    creating: vowpal_wabbit-8.5.0/cs/unittest/
#   inflating: vowpal_wabbit-8.5.0/cs/unittest/App.config
#   inflating: vowpal_wabbit-8.5.0/cs/unittest/ApplicationInsights.config
#   inflating: vowpal_wabbit-8.5.0/cs/unittest/BaseData.cs
#   inflating: vowpal_wabbit-8.5.0/cs/unittest/CbAdfData.cs
#    creating: vowpal_wabbit-8.5.0/cs/unittest/Properties/
#   inflating: vowpal_wabbit-8.5.0/cs/unittest/Properties/AssemblyInfo.cs
#   inflating: vowpal_wabbit-8.5.0/cs/unittest/RunTests.tt
#   inflating: vowpal_wabbit-8.5.0/cs/unittest/RunTestsHelper.cs
#   inflating: vowpal_wabbit-8.5.0/cs/unittest/Test1and2.cs
#   inflating: vowpal_wabbit-8.5.0/cs/unittest/Test3.cs
#   inflating: vowpal_wabbit-8.5.0/cs/unittest/TestAllReduce.cs
#   inflating: vowpal_wabbit-8.5.0/cs/unittest/TestAntlr.cs
#   inflating: vowpal_wabbit-8.5.0/cs/unittest/TestArguments.cs
#   inflating: vowpal_wabbit-8.5.0/cs/unittest/TestAzure.cs
#   inflating: vowpal_wabbit-8.5.0/cs/unittest/TestBase.cs
#   inflating: vowpal_wabbit-8.5.0/cs/unittest/TestCbAdf.cs
#   inflating: vowpal_wabbit-8.5.0/cs/unittest/TestConfidence.cs
#   inflating: vowpal_wabbit-8.5.0/cs/unittest/TestConfigInspector.cs
#   inflating: vowpal_wabbit-8.5.0/cs/unittest/TestConsole.cs
#   inflating: vowpal_wabbit-8.5.0/cs/unittest/TestDynamic.cs
#   inflating: vowpal_wabbit-8.5.0/cs/unittest/TestErrorListener.cs
#   inflating: vowpal_wabbit-8.5.0/cs/unittest/TestExampleCache.cs
#   inflating: vowpal_wabbit-8.5.0/cs/unittest/TestExpansion.cs
#   inflating: vowpal_wabbit-8.5.0/cs/unittest/TestFeatureExtraction.cs
#   inflating: vowpal_wabbit-8.5.0/cs/unittest/TestJson.cs
#   inflating: vowpal_wabbit-8.5.0/cs/unittest/TestJsonDict.cs
#   inflating: vowpal_wabbit-8.5.0/cs/unittest/TestJsonDirect.cs
#   inflating: vowpal_wabbit-8.5.0/cs/unittest/TestLabels.cs
#   inflating: vowpal_wabbit-8.5.0/cs/unittest/TestLeak.cs
#   inflating: vowpal_wabbit-8.5.0/cs/unittest/TestManagedHash.cs
#   inflating: vowpal_wabbit-8.5.0/cs/unittest/TestMarshalNumeric.cs
#   inflating: vowpal_wabbit-8.5.0/cs/unittest/TestMarshalNumeric.tt
#   inflating: vowpal_wabbit-8.5.0/cs/unittest/TestMarshalling.cs
#   inflating: vowpal_wabbit-8.5.0/cs/unittest/TestMarshallingOverflow.cs
#   inflating: vowpal_wabbit-8.5.0/cs/unittest/TestModelLoading.cs
#   inflating: vowpal_wabbit-8.5.0/cs/unittest/TestMultiClassPredictionFactory.cs
#   inflating: vowpal_wabbit-8.5.0/cs/unittest/TestMultiworldTesting.cs
#   inflating: vowpal_wabbit-8.5.0/cs/unittest/TestNull.cs
#   inflating: vowpal_wabbit-8.5.0/cs/unittest/TestPooling.cs
#   inflating: vowpal_wabbit-8.5.0/cs/unittest/TestRunner.cs
#   inflating: vowpal_wabbit-8.5.0/cs/unittest/TestSerializer.cs
#   inflating: vowpal_wabbit-8.5.0/cs/unittest/TestTelemetryProcessor.cs
#   inflating: vowpal_wabbit-8.5.0/cs/unittest/TestTracing.cs
#   inflating: vowpal_wabbit-8.5.0/cs/unittest/TestWiki.cs
#   inflating: vowpal_wabbit-8.5.0/cs/unittest/TestWrapper.cs
#   inflating: vowpal_wabbit-8.5.0/cs/unittest/TrainSet0002Dat.cs
#   inflating: vowpal_wabbit-8.5.0/cs/unittest/TrainSetCs_testLdf.cs
#   inflating: vowpal_wabbit-8.5.0/cs/unittest/VWTestHelper.cs
#   inflating: vowpal_wabbit-8.5.0/cs/unittest/VowpalWabbit.g4
#   inflating: vowpal_wabbit-8.5.0/cs/unittest/VowpalWabbitExampleJsonValidator.cs
#   inflating: vowpal_wabbit-8.5.0/cs/unittest/VowpalWabbitExampleValidator.cs
#   inflating: vowpal_wabbit-8.5.0/cs/unittest/VowpalWabbitListenerToEvents.cs
#   inflating: vowpal_wabbit-8.5.0/cs/unittest/VowpalWabbitStdErrPerformanceStatistics.cs
#   inflating: vowpal_wabbit-8.5.0/cs/unittest/azure.provision.ps1
#   inflating: vowpal_wabbit-8.5.0/cs/unittest/azuredeploy.json
#   inflating: vowpal_wabbit-8.5.0/cs/unittest/cs_unittest.csproj
#    creating: vowpal_wabbit-8.5.0/cs/unittest/json/
#   inflating: vowpal_wabbit-8.5.0/cs/unittest/json/test_array.json
#   inflating: vowpal_wabbit-8.5.0/cs/unittest/json/test_newline.json
#   inflating: vowpal_wabbit-8.5.0/cs/unittest/packages.config
#   inflating: vowpal_wabbit-8.5.0/cs/version.props
#  extracting: vowpal_wabbit-8.5.0/cs/vw_key.snk
#    creating: vowpal_wabbit-8.5.0/demo/
#    creating: vowpal_wabbit-8.5.0/demo/advertising/
#   inflating: vowpal_wabbit-8.5.0/demo/advertising/naive_baseline.py
#   inflating: vowpal_wabbit-8.5.0/demo/advertising/readme.txt
#    creating: vowpal_wabbit-8.5.0/demo/dependencyparsing/
#   inflating: vowpal_wabbit-8.5.0/demo/dependencyparsing/Makefile
#   inflating: vowpal_wabbit-8.5.0/demo/dependencyparsing/README.md
#   inflating: vowpal_wabbit-8.5.0/demo/dependencyparsing/evaluate.py
#   inflating: vowpal_wabbit-8.5.0/demo/dependencyparsing/parse_data.py
#   inflating: vowpal_wabbit-8.5.0/demo/dependencyparsing/parse_test_result.py
#   inflating: vowpal_wabbit-8.5.0/demo/dependencyparsing/tags
#   inflating: vowpal_wabbit-8.5.0/demo/dependencyparsing/wsj_test_subset
#   inflating: vowpal_wabbit-8.5.0/demo/dependencyparsing/wsj_train_subset
#    creating: vowpal_wabbit-8.5.0/demo/dna/
#   inflating: vowpal_wabbit-8.5.0/demo/dna/.gitignore
#   inflating: vowpal_wabbit-8.5.0/demo/dna/Makefile
#   inflating: vowpal_wabbit-8.5.0/demo/dna/README
#   inflating: vowpal_wabbit-8.5.0/demo/dna/do-dna-multicore-train
#   inflating: vowpal_wabbit-8.5.0/demo/dna/do-dnahogwild-multicore-train
#   inflating: vowpal_wabbit-8.5.0/demo/dna/do-dnahogwildnn-multicore-train
#   inflating: vowpal_wabbit-8.5.0/demo/dna/do-dnann-multicore-train
#   inflating: vowpal_wabbit-8.5.0/demo/dna/do-dnasmash-multicore-train
#   inflating: vowpal_wabbit-8.5.0/demo/dna/do-perf
#   inflating: vowpal_wabbit-8.5.0/demo/dna/do-test
#   inflating: vowpal_wabbit-8.5.0/demo/dna/map
#   inflating: vowpal_wabbit-8.5.0/demo/dna/quaddna2vw.cpp
#    creating: vowpal_wabbit-8.5.0/demo/entityrelation/
#   inflating: vowpal_wabbit-8.5.0/demo/entityrelation/README.md
#    creating: vowpal_wabbit-8.5.0/demo/mnist/
#   inflating: vowpal_wabbit-8.5.0/demo/mnist/.gitignore
#   inflating: vowpal_wabbit-8.5.0/demo/mnist/Makefile
#   inflating: vowpal_wabbit-8.5.0/demo/mnist/README
#   inflating: vowpal_wabbit-8.5.0/demo/mnist/do-mnist-hogwild-train
#   inflating: vowpal_wabbit-8.5.0/demo/mnist/do-mnist-train
#   inflating: vowpal_wabbit-8.5.0/demo/mnist/do-mnist11png-train
#   inflating: vowpal_wabbit-8.5.0/demo/mnist/do-mnist8m-train
#   inflating: vowpal_wabbit-8.5.0/demo/mnist/do-mnist8m11png-train
#   inflating: vowpal_wabbit-8.5.0/demo/mnist/do-mnist8mpng-train
#   inflating: vowpal_wabbit-8.5.0/demo/mnist/do-mnistpng-train
#   inflating: vowpal_wabbit-8.5.0/demo/mnist/do-pixelngram-test
#   inflating: vowpal_wabbit-8.5.0/demo/mnist/do-test
#   inflating: vowpal_wabbit-8.5.0/demo/mnist/extract-labels
#   inflating: vowpal_wabbit-8.5.0/demo/mnist/extractfeatures.cpp
#   inflating: vowpal_wabbit-8.5.0/demo/mnist/extractpixels.cpp
#   inflating: vowpal_wabbit-8.5.0/demo/mnist/map
#   inflating: vowpal_wabbit-8.5.0/demo/mnist/pixelngrams.cpp
#   inflating: vowpal_wabbit-8.5.0/demo/mnist/roundrobin
#    creating: vowpal_wabbit-8.5.0/demo/movielens/
#   inflating: vowpal_wabbit-8.5.0/demo/movielens/.gitignore
#   inflating: vowpal_wabbit-8.5.0/demo/movielens/Makefile
#   inflating: vowpal_wabbit-8.5.0/demo/movielens/README.md
#   inflating: vowpal_wabbit-8.5.0/demo/movielens/do-lrq-hogwild
#   inflating: vowpal_wabbit-8.5.0/demo/movielens/map
#   inflating: vowpal_wabbit-8.5.0/demo/movielens/ratings2vw
#   inflating: vowpal_wabbit-8.5.0/demo/movielens/visualize_factors.R
#    creating: vowpal_wabbit-8.5.0/demo/normalized/
#   inflating: vowpal_wabbit-8.5.0/demo/normalized/.gitignore
#   inflating: vowpal_wabbit-8.5.0/demo/normalized/Makefile
#   inflating: vowpal_wabbit-8.5.0/demo/normalized/README.md
#   inflating: vowpal_wabbit-8.5.0/demo/normalized/hypersearch
#    creating: vowpal_wabbit-8.5.0/demo/ocr/
#   inflating: vowpal_wabbit-8.5.0/demo/ocr/Makefile
#   inflating: vowpal_wabbit-8.5.0/demo/ocr/ocr2vw.py
#    creating: vowpal_wabbit-8.5.0/demo/random-noise/
#   inflating: vowpal_wabbit-8.5.0/demo/random-noise/Makefile
#   inflating: vowpal_wabbit-8.5.0/demo/random-noise/README
#   inflating: vowpal_wabbit-8.5.0/demo/random-noise/distrib.r
#   inflating: vowpal_wabbit-8.5.0/demo/random-noise/random-poly
#   inflating: vowpal_wabbit-8.5.0/demo/random-noise/vw-demo
#   inflating: vowpal_wabbit-8.5.0/demo/random-noise/x-vs-y.r
#    creating: vowpal_wabbit-8.5.0/demo/recall_tree/
#   inflating: vowpal_wabbit-8.5.0/demo/recall_tree/Makefile
#   inflating: vowpal_wabbit-8.5.0/demo/recall_tree/README.md
#    creating: vowpal_wabbit-8.5.0/demo/recall_tree/imagenet/
#   inflating: vowpal_wabbit-8.5.0/demo/recall_tree/imagenet/Makefile
#   inflating: vowpal_wabbit-8.5.0/demo/recall_tree/imagenet/README.md
#   inflating: vowpal_wabbit-8.5.0/demo/recall_tree/imagenet/do-oaa-hogwild
#   inflating: vowpal_wabbit-8.5.0/demo/recall_tree/imagenet/map
#    creating: vowpal_wabbit-8.5.0/demo/recall_tree/ltcb/
#   inflating: vowpal_wabbit-8.5.0/demo/recall_tree/ltcb/Makefile
#   inflating: vowpal_wabbit-8.5.0/demo/recall_tree/ltcb/README.md
#   inflating: vowpal_wabbit-8.5.0/demo/recall_tree/ltcb/do-oaa-hogwild
#   inflating: vowpal_wabbit-8.5.0/demo/recall_tree/ltcb/gendata.pl
#   inflating: vowpal_wabbit-8.5.0/demo/recall_tree/ltcb/map
#   inflating: vowpal_wabbit-8.5.0/demo/recall_tree/ltcb/wikifil.pl
#    creating: vowpal_wabbit-8.5.0/demo/recall_tree/odp/
#   inflating: vowpal_wabbit-8.5.0/demo/recall_tree/odp/Makefile
#   inflating: vowpal_wabbit-8.5.0/demo/recall_tree/odp/README.md
#   inflating: vowpal_wabbit-8.5.0/demo/recall_tree/odp/do-oaa-hogwild
#   inflating: vowpal_wabbit-8.5.0/demo/recall_tree/odp/map
#   inflating: vowpal_wabbit-8.5.0/demo/recall_tree/odp/minishuf
#    creating: vowpal_wabbit-8.5.0/demo/recall_tree/wikipara/
#   inflating: vowpal_wabbit-8.5.0/demo/recall_tree/wikipara/.gitignore
#   inflating: vowpal_wabbit-8.5.0/demo/recall_tree/wikipara/DocGenerator.py
#   inflating: vowpal_wabbit-8.5.0/demo/recall_tree/wikipara/Makefile
#   inflating: vowpal_wabbit-8.5.0/demo/recall_tree/wikipara/README.md
#   inflating: vowpal_wabbit-8.5.0/demo/recall_tree/wikipara/WikiExtractor.py
#   inflating: vowpal_wabbit-8.5.0/demo/recall_tree/wikipara/makeparadata.py
#   inflating: vowpal_wabbit-8.5.0/depcomp
#    creating: vowpal_wabbit-8.5.0/deploy_vw/
#   inflating: vowpal_wabbit-8.5.0/deploy_vw/deploy_vw.vcxproj
#   inflating: vowpal_wabbit-8.5.0/deployvw.bat
#    creating: vowpal_wabbit-8.5.0/doc/
#   inflating: vowpal_wabbit-8.5.0/doc/Doxyfile
#   inflating: vowpal_wabbit-8.5.0/doc/DoxygenLayout.xml
#   inflating: vowpal_wabbit-8.5.0/doc/Makefile
#    creating: vowpal_wabbit-8.5.0/explore/
#    creating: vowpal_wabbit-8.5.0/explore/cpp/
#   inflating: vowpal_wabbit-8.5.0/explore/cpp/MWTExplorer.h
#  extracting: vowpal_wabbit-8.5.0/explore/cpp/Makefile
#   inflating: vowpal_wabbit-8.5.0/explore/cpp/README
#   inflating: vowpal_wabbit-8.5.0/explore/cpp/utility.h
#   inflating: vowpal_wabbit-8.5.0/install-sh
#    creating: vowpal_wabbit-8.5.0/java/
#   inflating: vowpal_wabbit-8.5.0/java/Makefile
#   inflating: vowpal_wabbit-8.5.0/java/README.md
#   inflating: vowpal_wabbit-8.5.0/java/pom.xml
#    creating: vowpal_wabbit-8.5.0/java/src/
#    creating: vowpal_wabbit-8.5.0/java/src/main/
#    creating: vowpal_wabbit-8.5.0/java/src/main/c++/
#   inflating: vowpal_wabbit-8.5.0/java/src/main/c++/jni_base_learner.cc
#   inflating: vowpal_wabbit-8.5.0/java/src/main/c++/jni_base_learner.h
#   inflating: vowpal_wabbit-8.5.0/java/src/main/c++/vowpalWabbit_VW.cc
#   inflating: vowpal_wabbit-8.5.0/java/src/main/c++/vowpalWabbit_VW.h
#   inflating: vowpal_wabbit-8.5.0/java/src/main/c++/vowpalWabbit_learner_VWActionProbsLearner.cc
#   inflating: vowpal_wabbit-8.5.0/java/src/main/c++/vowpalWabbit_learner_VWActionProbsLearner.h
#   inflating: vowpal_wabbit-8.5.0/java/src/main/c++/vowpalWabbit_learner_VWActionScoresLearner.cc
#   inflating: vowpal_wabbit-8.5.0/java/src/main/c++/vowpalWabbit_learner_VWActionScoresLearner.h
#   inflating: vowpal_wabbit-8.5.0/java/src/main/c++/vowpalWabbit_learner_VWLearners.cc
#   inflating: vowpal_wabbit-8.5.0/java/src/main/c++/vowpalWabbit_learner_VWLearners.h
#   inflating: vowpal_wabbit-8.5.0/java/src/main/c++/vowpalWabbit_learner_VWMulticlassLearner.cc
#   inflating: vowpal_wabbit-8.5.0/java/src/main/c++/vowpalWabbit_learner_VWMulticlassLearner.h
#   inflating: vowpal_wabbit-8.5.0/java/src/main/c++/vowpalWabbit_learner_VWMultilabelsLearner.cc
#   inflating: vowpal_wabbit-8.5.0/java/src/main/c++/vowpalWabbit_learner_VWMultilabelsLearner.h
#   inflating: vowpal_wabbit-8.5.0/java/src/main/c++/vowpalWabbit_learner_VWProbLearner.cc
#   inflating: vowpal_wabbit-8.5.0/java/src/main/c++/vowpalWabbit_learner_VWProbLearner.h
#   inflating: vowpal_wabbit-8.5.0/java/src/main/c++/vowpalWabbit_learner_VWScalarLearner.cc
#   inflating: vowpal_wabbit-8.5.0/java/src/main/c++/vowpalWabbit_learner_VWScalarLearner.h
#   inflating: vowpal_wabbit-8.5.0/java/src/main/c++/vowpalWabbit_learner_VWScalarsLearner.cc
#   inflating: vowpal_wabbit-8.5.0/java/src/main/c++/vowpalWabbit_learner_VWScalarsLearner.h
#    creating: vowpal_wabbit-8.5.0/java/src/main/java/
#    creating: vowpal_wabbit-8.5.0/java/src/main/java/vowpalWabbit/
#   inflating: vowpal_wabbit-8.5.0/java/src/main/java/vowpalWabbit/VW.java
#    creating: vowpal_wabbit-8.5.0/java/src/main/java/vowpalWabbit/learner/
#   inflating: vowpal_wabbit-8.5.0/java/src/main/java/vowpalWabbit/learner/VWActionProbsLearner.java
#   inflating: vowpal_wabbit-8.5.0/java/src/main/java/vowpalWabbit/learner/VWActionScoresLearner.java
#   inflating: vowpal_wabbit-8.5.0/java/src/main/java/vowpalWabbit/learner/VWBase.java
#   inflating: vowpal_wabbit-8.5.0/java/src/main/java/vowpalWabbit/learner/VWFloatLearner.java
#   inflating: vowpal_wabbit-8.5.0/java/src/main/java/vowpalWabbit/learner/VWIntLearner.java
#   inflating: vowpal_wabbit-8.5.0/java/src/main/java/vowpalWabbit/learner/VWLearner.java
#   inflating: vowpal_wabbit-8.5.0/java/src/main/java/vowpalWabbit/learner/VWLearnerBase.java
#   inflating: vowpal_wabbit-8.5.0/java/src/main/java/vowpalWabbit/learner/VWLearners.java
#   inflating: vowpal_wabbit-8.5.0/java/src/main/java/vowpalWabbit/learner/VWMulticlassLearner.java
#   inflating: vowpal_wabbit-8.5.0/java/src/main/java/vowpalWabbit/learner/VWMultilabelsLearner.java
#   inflating: vowpal_wabbit-8.5.0/java/src/main/java/vowpalWabbit/learner/VWProbLearner.java
#   inflating: vowpal_wabbit-8.5.0/java/src/main/java/vowpalWabbit/learner/VWScalarLearner.java
#   inflating: vowpal_wabbit-8.5.0/java/src/main/java/vowpalWabbit/learner/VWScalarsLearner.java
#   inflating: vowpal_wabbit-8.5.0/java/src/main/java/vowpalWabbit/learner/VWTypedLearner.java
#   inflating: vowpal_wabbit-8.5.0/java/src/main/java/vowpalWabbit/learner/package-info.java
#   inflating: vowpal_wabbit-8.5.0/java/src/main/java/vowpalWabbit/package-info.java
#    creating: vowpal_wabbit-8.5.0/java/src/main/java/vowpalWabbit/responses/
#   inflating: vowpal_wabbit-8.5.0/java/src/main/java/vowpalWabbit/responses/ActionProb.java
#   inflating: vowpal_wabbit-8.5.0/java/src/main/java/vowpalWabbit/responses/ActionProbs.java
#   inflating: vowpal_wabbit-8.5.0/java/src/main/java/vowpalWabbit/responses/ActionScore.java
#   inflating: vowpal_wabbit-8.5.0/java/src/main/java/vowpalWabbit/responses/ActionScores.java
#   inflating: vowpal_wabbit-8.5.0/java/src/main/java/vowpalWabbit/responses/Multilabels.java
#    creating: vowpal_wabbit-8.5.0/java/src/test/
#    creating: vowpal_wabbit-8.5.0/java/src/test/java/
#    creating: vowpal_wabbit-8.5.0/java/src/test/java/vowpalWabbit/
#   inflating: vowpal_wabbit-8.5.0/java/src/test/java/vowpalWabbit/ClosingTest.java
#   inflating: vowpal_wabbit-8.5.0/java/src/test/java/vowpalWabbit/VWTestHelper.java
#    creating: vowpal_wabbit-8.5.0/java/src/test/java/vowpalWabbit/learner/
#   inflating: vowpal_wabbit-8.5.0/java/src/test/java/vowpalWabbit/learner/VWActionProbsLearnerTest.java
#   inflating: vowpal_wabbit-8.5.0/java/src/test/java/vowpalWabbit/learner/VWActionScoresLearnerTest.java
#   inflating: vowpal_wabbit-8.5.0/java/src/test/java/vowpalWabbit/learner/VWLearnersTest.java
#   inflating: vowpal_wabbit-8.5.0/java/src/test/java/vowpalWabbit/learner/VWMulticlassLearnerTest.java
#   inflating: vowpal_wabbit-8.5.0/java/src/test/java/vowpalWabbit/learner/VWMultilabelsLearnerTest.java
#   inflating: vowpal_wabbit-8.5.0/java/src/test/java/vowpalWabbit/learner/VWProbLearnerTest.java
#   inflating: vowpal_wabbit-8.5.0/java/src/test/java/vowpalWabbit/learner/VWScalarLearnerTest.java
#   inflating: vowpal_wabbit-8.5.0/java/src/test/java/vowpalWabbit/learner/VWScalarsLearnerTest.java
#    creating: vowpal_wabbit-8.5.0/java/src/test/resources/
#   inflating: vowpal_wabbit-8.5.0/java/src/test/resources/vw_7.8.model
#   inflating: vowpal_wabbit-8.5.0/java/src/test/resources/vw_bad.model
#    creating: vowpal_wabbit-8.5.0/library/
#   inflating: vowpal_wabbit-8.5.0/library/Makefile.am
#   inflating: vowpal_wabbit-8.5.0/library/Makefile.in
#   inflating: vowpal_wabbit-8.5.0/library/ezexample_predict.cc
#   inflating: vowpal_wabbit-8.5.0/library/ezexample_predict_threaded.cc
#   inflating: vowpal_wabbit-8.5.0/library/ezexample_train.cc
#   inflating: vowpal_wabbit-8.5.0/library/gd_mf_weights.cc
#   inflating: vowpal_wabbit-8.5.0/library/library_example.cc
#   inflating: vowpal_wabbit-8.5.0/library/libsearch.h
#   inflating: vowpal_wabbit-8.5.0/library/recommend.cc
#   inflating: vowpal_wabbit-8.5.0/library/search_generate.cc
#   inflating: vowpal_wabbit-8.5.0/library/test.cc
#   inflating: vowpal_wabbit-8.5.0/library/test_search.cc
#   inflating: vowpal_wabbit-8.5.0/library/train
#   inflating: vowpal_wabbit-8.5.0/library/train.sh
#   inflating: vowpal_wabbit-8.5.0/libtool
#   inflating: vowpal_wabbit-8.5.0/libvw.pc.in
#   inflating: vowpal_wabbit-8.5.0/libvw_c_wrapper.pc.in
#    creating: vowpal_wabbit-8.5.0/logo_assets/
#   inflating: vowpal_wabbit-8.5.0/logo_assets/vowpal-wabbits-brand-image.jpg
#   inflating: vowpal_wabbit-8.5.0/logo_assets/vowpal-wabbits-color-palette.png
#   inflating: vowpal_wabbit-8.5.0/logo_assets/vowpal-wabbits-github-logo.png
#   inflating: vowpal_wabbit-8.5.0/logo_assets/vowpal-wabbits-github-logo@2x.png
#   inflating: vowpal_wabbit-8.5.0/logo_assets/vowpal-wabbits-github-logo@3x.png
#   inflating: vowpal_wabbit-8.5.0/logo_assets/vowpal-wabbits-icon-400x400.png
#   inflating: vowpal_wabbit-8.5.0/logo_assets/vowpal-wabbits-icon-800x800.png
#   inflating: vowpal_wabbit-8.5.0/logo_assets/vowpal-wabbits-icon.eps
#   inflating: vowpal_wabbit-8.5.0/logo_assets/vowpal-wabbits-icon.pdf
#   inflating: vowpal_wabbit-8.5.0/logo_assets/vowpal-wabbits-icon.svg
#   inflating: vowpal_wabbit-8.5.0/logo_assets/vowpal-wabbits-logomark-1000x1000.png
#   inflating: vowpal_wabbit-8.5.0/logo_assets/vowpal-wabbits-logomark-2000x2000.png
#   inflating: vowpal_wabbit-8.5.0/logo_assets/vowpal-wabbits-logomark.eps
#   inflating: vowpal_wabbit-8.5.0/logo_assets/vowpal-wabbits-logomark.pdf
#   inflating: vowpal_wabbit-8.5.0/logo_assets/vowpal-wabbits-logomark.svg
#   inflating: vowpal_wabbit-8.5.0/ltmain.sh
#   inflating: vowpal_wabbit-8.5.0/missing
#   inflating: vowpal_wabbit-8.5.0/mkdevdist.sh
#    creating: vowpal_wabbit-8.5.0/python/
#   inflating: vowpal_wabbit-8.5.0/python/MANIFEST.in
#   inflating: vowpal_wabbit-8.5.0/python/Makefile
#   inflating: vowpal_wabbit-8.5.0/python/PACKAGE.rst
#   inflating: vowpal_wabbit-8.5.0/python/README.rst
#    creating: vowpal_wabbit-8.5.0/python/examples/
#   inflating: vowpal_wabbit-8.5.0/python/examples/Learning_to_Search.ipynb
#   inflating: vowpal_wabbit-8.5.0/python/examples/Uncertainty_Scores_and_Prediction_Errors.ipynb
#   inflating: vowpal_wabbit-8.5.0/python/examples/VW_in_Python.ipynb
#   inflating: vowpal_wabbit-8.5.0/python/examples/covington.py
#   inflating: vowpal_wabbit-8.5.0/python/examples/mini_vw.py
#   inflating: vowpal_wabbit-8.5.0/python/examples/poisson_regression.ipynb
#   inflating: vowpal_wabbit-8.5.0/python/examples/sklearn_vw.ipynb
#   inflating: vowpal_wabbit-8.5.0/python/examples/test.py
#   inflating: vowpal_wabbit-8.5.0/python/examples/test_partial_example.py
#   inflating: vowpal_wabbit-8.5.0/python/examples/test_search.py
#   inflating: vowpal_wabbit-8.5.0/python/examples/test_search_ldf.py
#   inflating: vowpal_wabbit-8.5.0/python/examples/word_alignment.py
#   inflating: vowpal_wabbit-8.5.0/python/examples/xor.py
#   inflating: vowpal_wabbit-8.5.0/python/pylibvw.cc
#   inflating: vowpal_wabbit-8.5.0/python/requirements.txt
#   inflating: vowpal_wabbit-8.5.0/python/setup.py
#    creating: vowpal_wabbit-8.5.0/python/tests/
#    creating: vowpal_wabbit-8.5.0/python/tests/resources/
#   inflating: vowpal_wabbit-8.5.0/python/tests/resources/train.dat
#   inflating: vowpal_wabbit-8.5.0/python/tests/test_pyvw.py
#   inflating: vowpal_wabbit-8.5.0/python/tests/test_sklearn_vw.py
#   inflating: vowpal_wabbit-8.5.0/python/tox.ini
#    creating: vowpal_wabbit-8.5.0/python/vowpalwabbit/
#  extracting: vowpal_wabbit-8.5.0/python/vowpalwabbit/__init__.py
#   inflating: vowpal_wabbit-8.5.0/python/vowpalwabbit/pyvw.py
#   inflating: vowpal_wabbit-8.5.0/python/vowpalwabbit/sklearn_vw.py
#    creating: vowpal_wabbit-8.5.0/python/windows27/
#   inflating: vowpal_wabbit-8.5.0/python/windows27/packages.config
#   inflating: vowpal_wabbit-8.5.0/python/windows27/python27.vcxproj
#   inflating: vowpal_wabbit-8.5.0/python/windows27/python27.vcxproj.filters
#    creating: vowpal_wabbit-8.5.0/python/windows35/
#   inflating: vowpal_wabbit-8.5.0/python/windows35/packages.config
#   inflating: vowpal_wabbit-8.5.0/python/windows35/python35.vcxproj
#   inflating: vowpal_wabbit-8.5.0/python/windows35/python35.vcxproj.filters
#    creating: vowpal_wabbit-8.5.0/python/windows36/
#   inflating: vowpal_wabbit-8.5.0/python/windows36/packages.config
#   inflating: vowpal_wabbit-8.5.0/python/windows36/python36.vcxproj
#   inflating: vowpal_wabbit-8.5.0/python/windows36/python36.vcxproj.filters
#   inflating: vowpal_wabbit-8.5.0/python/windows_build.bat
#    creating: vowpal_wabbit-8.5.0/rapidjson/
#   inflating: vowpal_wabbit-8.5.0/rapidjson/.gitattributes
#   inflating: vowpal_wabbit-8.5.0/rapidjson/.gitignore
#   inflating: vowpal_wabbit-8.5.0/rapidjson/.travis.yml
#   inflating: vowpal_wabbit-8.5.0/rapidjson/CHANGELOG.md
#   inflating: vowpal_wabbit-8.5.0/rapidjson/CMakeLists.txt
#    creating: vowpal_wabbit-8.5.0/rapidjson/CMakeModules/
#   inflating: vowpal_wabbit-8.5.0/rapidjson/CMakeModules/FindGTestSrc.cmake
#   inflating: vowpal_wabbit-8.5.0/rapidjson/RapidJSON.pc.in
#   inflating: vowpal_wabbit-8.5.0/rapidjson/RapidJSONConfig.cmake.in
#   inflating: vowpal_wabbit-8.5.0/rapidjson/RapidJSONConfigVersion.cmake.in
#   inflating: vowpal_wabbit-8.5.0/rapidjson/appveyor.yml
#    creating: vowpal_wabbit-8.5.0/rapidjson/bin/
#    creating: vowpal_wabbit-8.5.0/rapidjson/bin/data/
#   inflating: vowpal_wabbit-8.5.0/rapidjson/bin/data/glossary.json
#   inflating: vowpal_wabbit-8.5.0/rapidjson/bin/data/menu.json
#   inflating: vowpal_wabbit-8.5.0/rapidjson/bin/data/readme.txt
#   inflating: vowpal_wabbit-8.5.0/rapidjson/bin/data/sample.json
#   inflating: vowpal_wabbit-8.5.0/rapidjson/bin/data/webapp.json
#   inflating: vowpal_wabbit-8.5.0/rapidjson/bin/data/widget.json
#    creating: vowpal_wabbit-8.5.0/rapidjson/bin/draft-04/
#   inflating: vowpal_wabbit-8.5.0/rapidjson/bin/draft-04/schema
#    creating: vowpal_wabbit-8.5.0/rapidjson/bin/encodings/
#   inflating: vowpal_wabbit-8.5.0/rapidjson/bin/encodings/utf16be.json
#   inflating: vowpal_wabbit-8.5.0/rapidjson/bin/encodings/utf16bebom.json
#   inflating: vowpal_wabbit-8.5.0/rapidjson/bin/encodings/utf16le.json
#   inflating: vowpal_wabbit-8.5.0/rapidjson/bin/encodings/utf16lebom.json
#   inflating: vowpal_wabbit-8.5.0/rapidjson/bin/encodings/utf32be.json
#   inflating: vowpal_wabbit-8.5.0/rapidjson/bin/encodings/utf32bebom.json
#   inflating: vowpal_wabbit-8.5.0/rapidjson/bin/encodings/utf32le.json
#   inflating: vowpal_wabbit-8.5.0/rapidjson/bin/encodings/utf32lebom.json
#   inflating: vowpal_wabbit-8.5.0/rapidjson/bin/encodings/utf8.json
#   inflating: vowpal_wabbit-8.5.0/rapidjson/bin/encodings/utf8bom.json
#    creating: vowpal_wabbit-8.5.0/rapidjson/bin/jsonchecker/
#  extracting: vowpal_wabbit-8.5.0/rapidjson/bin/jsonchecker/fail1.json
#   inflating: vowpal_wabbit-8.5.0/rapidjson/bin/jsonchecker/fail10.json
#  extracting: vowpal_wabbit-8.5.0/rapidjson/bin/jsonchecker/fail11.json
#  extracting: vowpal_wabbit-8.5.0/rapidjson/bin/jsonchecker/fail12.json
# ...
#  extracting: vowpal_wabbit-8.5.0/test/train-sets/ref/wsj_small-tm.dat.stdout
#   inflating: vowpal_wabbit-8.5.0/test/train-sets/ref/wsj_small.dat.stderr
#  extracting: vowpal_wabbit-8.5.0/test/train-sets/ref/wsj_small.dat.stdout
#   inflating: vowpal_wabbit-8.5.0/test/train-sets/ref/xxor.stderr
#  extracting: vowpal_wabbit-8.5.0/test/train-sets/ref/xxor.stdout
#   inflating: vowpal_wabbit-8.5.0/test/train-sets/ref/zero.stderr
#  extracting: vowpal_wabbit-8.5.0/test/train-sets/ref/zero.stdout
#   inflating: vowpal_wabbit-8.5.0/test/train-sets/seq_small
#   inflating: vowpal_wabbit-8.5.0/test/train-sets/seq_small.tm1
#   inflating: vowpal_wabbit-8.5.0/test/train-sets/seq_small2
#   inflating: vowpal_wabbit-8.5.0/test/train-sets/sequence_data
#   inflating: vowpal_wabbit-8.5.0/test/train-sets/sequencespan_data
#   inflating: vowpal_wabbit-8.5.0/test/train-sets/slate.vw
#   inflating: vowpal_wabbit-8.5.0/test/train-sets/slate.vw.readme
#   inflating: vowpal_wabbit-8.5.0/test/train-sets/test_named
#   inflating: vowpal_wabbit-8.5.0/test/train-sets/test_named_csoaa
#   inflating: vowpal_wabbit-8.5.0/test/train-sets/topk.vw
#   inflating: vowpal_wabbit-8.5.0/test/train-sets/wiki256.dat
#   inflating: vowpal_wabbit-8.5.0/test/train-sets/wsj.classes
#   inflating: vowpal_wabbit-8.5.0/test/train-sets/wsj.train.tm2
#  extracting: vowpal_wabbit-8.5.0/test/train-sets/wsj_small.dat.gz
#  extracting: vowpal_wabbit-8.5.0/test/train-sets/wsj_small.dparser.vw.gz
#   inflating: vowpal_wabbit-8.5.0/test/train-sets/x.txt
#   inflating: vowpal_wabbit-8.5.0/test/train-sets/xxor.dat
#   inflating: vowpal_wabbit-8.5.0/test/train-sets/zero.dat
#    creating: vowpal_wabbit-8.5.0/utl/
#   inflating: vowpal_wabbit-8.5.0/utl/active_interactor.py
#   inflating: vowpal_wabbit-8.5.0/utl/csv2vw
#   inflating: vowpal_wabbit-8.5.0/utl/logistic
#   inflating: vowpal_wabbit-8.5.0/utl/new_version
#   inflating: vowpal_wabbit-8.5.0/utl/release.ps1
#   inflating: vowpal_wabbit-8.5.0/utl/vw-convergence
#   inflating: vowpal_wabbit-8.5.0/utl/vw-csv2bin
#   inflating: vowpal_wabbit-8.5.0/utl/vw-doc2lda
#   inflating: vowpal_wabbit-8.5.0/utl/vw-experiment
#   inflating: vowpal_wabbit-8.5.0/utl/vw-format.pl
#   inflating: vowpal_wabbit-8.5.0/utl/vw-hyperopt.py
#   inflating: vowpal_wabbit-8.5.0/utl/vw-hypersearch
#   inflating: vowpal_wabbit-8.5.0/utl/vw-lda
#   inflating: vowpal_wabbit-8.5.0/utl/vw-regr
#   inflating: vowpal_wabbit-8.5.0/utl/vw-top-errors
#   inflating: vowpal_wabbit-8.5.0/utl/vw-validate.html
#   inflating: vowpal_wabbit-8.5.0/utl/vw-varinfo
#   inflating: vowpal_wabbit-8.5.0/utl/vw2csv
#    creating: vowpal_wabbit-8.5.0/vowpalwabbit/
#    creating: vowpal_wabbit-8.5.0/vowpalwabbit/.nuget/
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/.nuget/NuGet.Config
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/.nuget/NuGet.exe
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/.nuget/NuGet.targets
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/Build.props
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/Makefile.am
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/Makefile.in
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/OjaNewton.cc
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/OjaNewton.h
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/accumulate.cc
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/accumulate.h
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/action_score.cc
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/action_score.h
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/active.cc
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/active.h
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/active_cover.cc
#  extracting: vowpal_wabbit-8.5.0/vowpalwabbit/active_cover.h
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/active_interactor.cc
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/allreduce.h
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/allreduce_sockets.cc
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/allreduce_threads.cc
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/array_parameters.h
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/audit_regressor.cc
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/audit_regressor.h
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/autolink.cc
#  extracting: vowpal_wabbit-8.5.0/vowpalwabbit/autolink.h
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/baseline.cc
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/baseline.h
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/beam.h
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/best_constant.cc
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/best_constant.h
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/bfgs.cc
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/bfgs.h
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/binary.cc
#  extracting: vowpal_wabbit-8.5.0/vowpalwabbit/binary.h
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/boosting.cc
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/boosting.h
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/bs.cc
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/bs.h
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/cache.cc
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/cache.h
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/cb.cc
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/cb.h
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/cb_adf.cc
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/cb_adf.h
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/cb_algs.cc
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/cb_algs.h
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/cb_explore.cc
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/cb_explore.h
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/cb_explore_adf.cc
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/cb_explore_adf.h
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/cbify.cc
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/cbify.h
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/classweight.cc
#  extracting: vowpal_wabbit-8.5.0/vowpalwabbit/classweight.h
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/comp_io.cc
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/comp_io.h
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/confidence.cc
#  extracting: vowpal_wabbit-8.5.0/vowpalwabbit/confidence.h
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/config.h.in
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/constant.h
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/correctedMath.h
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/cost_sensitive.cc
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/cost_sensitive.h
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/crossplat_compat.h
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/cs_active.cc
#  extracting: vowpal_wabbit-8.5.0/vowpalwabbit/cs_active.h
#    creating: vowpal_wabbit-8.5.0/vowpalwabbit/cs_testcommon/
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/cs_testcommon/ITestCommunication.cs
#    creating: vowpal_wabbit-8.5.0/vowpalwabbit/cs_testcommon/Properties/
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/cs_testcommon/Properties/AssemblyInfo.cs
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/cs_testcommon/cs_testcommon.csproj
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/cs_unittest.testsettings
#    creating: vowpal_wabbit-8.5.0/vowpalwabbit/cs_vld/
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/cs_vld/cs_vld.vcxproj
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/csoaa.cc
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/csoaa.h
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/ect.cc
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/ect.h
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/example.cc
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/example.h
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/explore_eval.cc
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/explore_eval.h
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/expreplay.h
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/ezexample.h
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/feature_group.h
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/floatbits.h
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/ftrl.cc
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/ftrl.h
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/gd.cc
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/gd.h
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/gd_mf.cc
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/gd_mf.h
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/gen_cs_example.cc
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/gen_cs_example.h
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/global_data.cc
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/global_data.h
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/hash.cc
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/hash.h
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/interact.cc
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/interact.h
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/interactions.cc
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/interactions.h
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/io_buf.cc
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/io_buf.h
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/kernel_svm.cc
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/kernel_svm.h
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/label_dictionary.cc
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/label_dictionary.h
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/label_parser.h
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/lda_core.cc
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/lda_core.h
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/learner.cc
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/learner.h
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/libvw.vcxproj
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/log_multi.cc
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/log_multi.h
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/loss_functions.cc
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/loss_functions.h
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/lrq.cc
#  extracting: vowpal_wabbit-8.5.0/vowpalwabbit/lrq.h
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/lrqfa.cc
#  extracting: vowpal_wabbit-8.5.0/vowpalwabbit/lrqfa.h
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/main.cc
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/marginal.cc
#  extracting: vowpal_wabbit-8.5.0/vowpalwabbit/marginal.h
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/memory.h
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/mf.cc
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/mf.h
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/multiclass.cc
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/multiclass.h
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/multilabel.cc
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/multilabel.h
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/multilabel_oaa.cc
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/multilabel_oaa.h
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/mwt.cc
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/mwt.h
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/network.cc
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/network.h
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/nn.cc
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/nn.h
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/noop.cc
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/noop.h
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/oaa.cc
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/oaa.h
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/packages.config
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/parse_args.cc
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/parse_args.h
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/parse_example.cc
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/parse_example.h
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/parse_example_json.cc
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/parse_example_json.h
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/parse_primitives.cc
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/parse_primitives.h
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/parse_regressor.cc
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/parse_regressor.h
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/parser.cc
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/parser.h
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/primitives.cc
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/primitives.h
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/print.cc
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/print.h
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/rand48.cc
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/rand48.h
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/recall_tree.cc
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/recall_tree.h
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/reductions.h
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/scorer.cc
#  extracting: vowpal_wabbit-8.5.0/vowpalwabbit/scorer.h
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/search.cc
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/search.h
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/search_dep_parser.cc
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/search_dep_parser.h
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/search_entityrelationtask.cc
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/search_entityrelationtask.h
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/search_graph.cc
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/search_graph.h
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/search_hooktask.cc
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/search_hooktask.h
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/search_meta.cc
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/search_meta.h
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/search_multiclasstask.cc
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/search_multiclasstask.h
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/search_sequencetask.cc
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/search_sequencetask.h
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/sender.cc
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/sender.h
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/simple_label.cc
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/simple_label.h
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/spanning_tree.cc
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/spanning_tree.h
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/stagewise_poly.cc
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/stagewise_poly.h
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/svrg.cc
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/svrg.h
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/topk.cc
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/topk.h
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/unique_sort.cc
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/unique_sort.h
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/v_array.h
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/v_hashmap.h
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/vw.h
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/vw.sln
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/vw.vcxproj
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/vw_allreduce.h
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/vw_dynamic.vcxproj
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/vw_exception.cc
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/vw_exception.h
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/vw_validate.cc
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/vw_validate.h
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/vw_versions.h
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/vwdll.cpp
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/vwdll.h
#    creating: vowpal_wabbit-8.5.0/vowpalwabbit/win32/
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/win32/make_config_h.cs
#   inflating: vowpal_wabbit-8.5.0/vowpalwabbit/win32/make_config_h.exe
# finishing deferred symbolic links:
#   vowpal_wabbit-8.5.0/big_tests/README.txt -> HOWTO.use_it.txt

# %%
# !g++ vowpal_wabbit-8.5.0/library/recommend.cc \
    -o recommend \
    -std=c++0x \
    -lvw -lboost_program_options-mt

# %%
df[df["userId"] == 120].head()
# Out:
#        movieId  rating  userId    random
# 14407        2     1.0     120  0.538618
# 14408       11     3.0     120  0.698799
# 14409       19     3.0     120  0.157578
# 14410       21     5.0     120  0.420503
# 14411       36     4.0     120  0.061272

# %%
with open("blacklist.vw", "w") as f:
    for row in df[df["userId"] == 120].itertuples():
        f.write("|u 120 |i " + str(row.movieId) + "\n")

# %%
# !head blacklist.vw -n 2
# Out:
# |u 120 |i 2
# |u 120 |i 11

# %%
with open("items.vw", "w") as f:
    for i in range(1, len(df["movieId"].unique()) + 1):
        f.write("|i " + str(i) + "\n")

# %%
# !head items.vw -n 5
# Out:
# |i 1
# |i 2
# |i 3
# |i 4
# |i 5

# %%
# !echo '|u 120' | ./recommend \
    --topk 10 \
    -B blacklist.vw \
    -U /dev/stdin \
    -I items.vw \
    --vwparams '-i movielens.reg' >recommendations
# Out:
# creating quadratic features for pairs: ui
# Num weight bits = 18
# learning rate = 10
# initial_t = 1
# power_t = 0.5
# using no cache
# Reading datafile =
# num sources = 1
#
# finished run
# number of examples = 0
# weighted example sum = 0.000000
# weighted label sum = 0.000000
# average loss = n.a.
# total feature number = 0

# %%
# !cat recommendations
# Out:
# 4.48818	|u 120|i 844
# 4.49538	|u 120|i 3481
# 4.54713	|u 120|i 524
# 4.57014	|u 120|i 1243
# 4.58537	|u 120|i 7316
# 4.60624	|u 120|i 1945
# 4.64483	|u 120|i 1662
# 4.68453	|u 120|i 2677
# 4.69195	|u 120|i 316
# 4.85388	|u 120|i 353

# %%
movies = []

for line in open("recommendations"):
    movie_id = line.split()[-1]
    movies.append(int(movie_id))

# %%
movies
# Out:
# [844, 3481, 524, 1243, 7316, 1945, 1662, 2677, 316, 353]

# %%
df_movies = pd.read_csv("ml-20m/movies.csv")

# %%
df_movies[df_movies["movieId"].isin([index_to_item_id_mapping[t - 1] for t in movies])]
# Out:
#       movieId                             title                    genres
# 315       318  Shawshank Redemption, The (1994)               Crime|Drama
# 352       356               Forrest Gump (1994)  Comedy|Drama|Romance|War
# 523       527           Schindler's List (1993)                 Drama|War
# 843       858             Godfather, The (1972)               Crime|Drama
# 1242     1270         Back to the Future (1985)   Adventure|Comedy|Sci-Fi
# 1661     1721                    Titanic (1997)             Drama|Romance
# 1944     2028        Saving Private Ryan (1998)          Action|Drama|War
# 2676     2762           Sixth Sense, The (1999)      Drama|Horror|Mystery
# 3487     3578                  Gladiator (2000)    Action|Adventure|Drama
# 7356     7502           Band of Brothers (2001)          Action|Drama|War

# %% [markdown]
# ## Заключение

# %% [markdown]
# 1. Разобрались с VW и построили модель для рекомендаций на основе Factrorization Machines
# 2. Построили простую рекомендательную модель на основе SVD
